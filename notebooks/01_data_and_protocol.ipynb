# %% [markdown]
# # Data and protocol
#
# Nuno Antunes · Taxi Scale Lab
#
# Outputs below are executed; synthetic data is explicitly labelled.

# %%
from taxi_scale_lab.data import synthetic
import pandas as pd
df = synthetic(2000)
print('Synthetic software-check fixture:', len(df), 'rows')
# Out:
# Synthetic software-check fixture: 2000 rows

# %%
df.head()
# Out:
#       pickup_datetime  fare_amt  tip_amt  ...  start_lat    end_lon    end_lat
# 0 2015-01-12 03:19:05     13.86     1.26  ...  40.752632 -74.032033  40.789885
# 1 2015-01-06 04:47:18     23.98     3.74  ...  40.651075 -73.952758  40.881477
# 2 2015-01-15 23:36:19     12.71     2.63  ...  40.762401 -73.846340  40.721797
# 3 2015-01-05 19:05:06     12.85     0.78  ...  40.834721 -74.006702  40.715508
# 4 2015-01-25 11:35:35     19.36     1.66  ...  40.708810 -73.874681  40.695859
#
# [5 rows x 9 columns]

# %%
pd.DataFrame({'dtype': df.dtypes.astype(str), 'missing': df.isna().sum()})
# Out:
#                           dtype  missing
# pickup_datetime  datetime64[ns]        0
# fare_amt                float64        0
# tip_amt                 float64        0
# passenger_count           int64        0
# trip_distance           float64        0
# start_lon               float64        0
# start_lat               float64        0
# end_lon                 float64        0
# end_lat                 float64        0
